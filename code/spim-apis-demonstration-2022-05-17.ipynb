# %% [markdown]
# ![UWS Logo](./images/uws-logo-black.png)

# %% [markdown]
# # Application Programming Interfaces in Python

# %% [markdown]
# A tutorial as part of the *Spring into Methods 2022* training programme run by Scottish Graduate School of Social Science and the Scottish Graduate School for Arts & Humanities.

# %% [markdown]
# ## Introduction
#
# Application Programming Interfaces (APIs) have become one of the most important ways to access and transfer data online (Bail, 2021). There are a number of advantages to using APIs instead of web-scraping, in particular avoiding many of the legal or ethical issues associated with the latter. However APIs can use data formats and structures that are alien to researchers in the arts, humanities, and social sciences, and can enact access barriers of their own (e.g., subscriptions and fees for using the API).
#
# In this tutorial we provide an interactive introduction to APIs.

# %% [markdown]
# ### Aims
#
# This lesson - **Collecting data II: APIs** - has two aims:
# 1. Demonstrate how to use Python to download data from the web through an Application Programming Interface (API).
# 2. Cultivate your computational thinking skills through coding examples. In particular, how to define and solve a data collection problem using a computational method.

# %% [markdown]
# ### Lesson details
#
# * **Level**: Introductory
# * **Time**: 30-60 minutes
# * **Pre-requisites**: None, though you may find it useful to work through our <a href="https://github.com/UKDataServiceOpen/code-demos/blob/master/code/ukds-intro-to-python-2020-05-06.ipynb" target=_blank>*Introduction to Python for social scientists*</a> and <a href="https://github.com/UKDataServiceOpen/code-demos/blob/master/code/ukds-web-scraping-2020-05-13.ipynb" target=_blank>*Collecting data I: web-scraping*</a>  lessons first.
# * **Audience**: Researchers and analysts from any disciplinary background. The materials are slightly tailored for social scientists through the use of social data.
# * **Learning outcomes**:
#     1. Understand what an Application Programming Interface (API) is.
#     2. Understand the key steps and requirements for collecting data from the web through an API.
#     3. Be able to use Python for requesting, processing and saving data accessed through an API.

# %% [markdown]
# ## Guide to using this resource
#
# This learning resource was built using <a href="https://jupyter.org/" target=_blank>Jupyter Notebook</a>, an open-source software application that allows you to mix code, results and narrative in a single document. As <a href="https://jupyter4edu.github.io/jupyter-edu-book/" target=_blank>Barba et al. (2019)</a> espouse:
# > In a world where every subject matter can have a data-supported treatment, where computational devices are omnipresent and pervasive, the union of natural language and computation creates compelling communication and learning opportunities.
#
# If you are familiar with Jupyter notebooks then skip ahead to the main content (*What is an API?*). Otherwise, the following is a quick guide to navigating and interacting with the notebook.

# %% [markdown]
# ### Interaction
#
# **You only need to execute the code that is contained in sections which are marked by `In []`.**
#
# To execute a cell, click or double-click the cell and press the `Run` button on the top toolbar (you can also use the keyboard shortcut Shift + Enter).
#
# Try it for yourself:

# %%
print("Enter your name and press enter:")
name = input()
print("\r")
print("Hello {}, enjoy learning more about Python and APIs!".format(name))

# %% [markdown]
# ### Learn more
#
# Jupyter notebooks provide rich, flexible features for conducting and documenting your data analysis workflow. To learn more about additional notebook features, we recommend working through some of the <a href="https://github.com/darribas/gds19/blob/master/content/labs/lab_00.ipynb" target=_blank>materials</a> provided by Dani Arribas-Bel at the University of Liverpool.

# %% [markdown]
# ## What is an Application Programming Interface (API)?

# %% [markdown]
# An Application Programming Interface (API) is
# > a set of functions and procedures allowing the creation of applications that access the features or data of an operating system, application, or other service" (Oxford English Dictionary).
#
# In essence: an API acts as an intermediary between software applications. Think of an API's role as similar to that of a translator faciliating a conversation between two individuals who do not speak the same language. Neither individual needs to know the other's language, just how to formulate their response in a way the translator can understand. Similarly, an API **simplifies** how applications communicate with each other.

# %% [markdown]
# It performs this role by providing a set of protocols/standards for making *requests* and formulating *responses* between applications. For example, a smart phone application might need real-time traffic data from an online database. An API can validate the application's request for data, and handle the online database's response (i.e., the transfer of data to the application). In the absence of an API, the smart phone application would need to know a lot more technical information about the online database in order to communicate with it (e.g., what commands does the database understand?). But thanks to the API, the smart phone application only needs to know how to formulate a request that the API understands, which then communicates the request to the database and handles the response.

# %% [markdown]
# ### Why would you want to use an API?

# %% [markdown]
# While APIs have much broader uses, researchers are primarily interested in using them to access online databases. You may have heard or be familiar with some of these APIs: Twitter API, YouTube API, Google Maps API. At time of writing (2022-05-05), there were over 24,000 public APIs listed on the website [Programmable Web](https://www.programmableweb.com/apis/directory).
#
# Many public, private and charitable institutions collect and share data of value to researchers in the arts, humanities and social sciences. Often they deposit their data to a data portal - e.g., <a href="https://data.gov.uk/" target=_blank>UK Government Open Data</a> -, allowing you to download the files as and when needed. However, another approach they can adopt is to allow access to the underlying information that is stored in their database through an API. Using this method, individuals can send a customised *request* for information to the database; if the request is valid, the database *responds* by providing you with the information you asked for. Think of using an API as the difference between downloading a raw data file which then needs to be filtered to arrive at the information you need, and performing the filtering when you request the data, so only what you need is returned.

# %% [markdown]
# ### What is the general approach for accessing data through an API?

# %% [markdown]
# We begin by identifying an API containing data of interest. Then we need to **know** the following:
# * The location of the API (i.e., web address). For example, the UK Police API can be accessed via <a href="https://data.police.uk/api" target=_blank>https://data.police.uk/api</a>.
# * The terms of use associated with the API. Many APIs restrict the number of requests you can make over a given time period, while others require registration in order to authenticate who is trying to access the data. For example, the UK Police API does not require you to provide authentication but restricts the number of requests for data you can make (15 per second) - the number of allowable requests in a given time period is known as the *rate limit*.
# * The location of the data of interest on the API. For example, data on street-level crime from the UK Police API is available at: <a href="https://data.police.uk/api/crimes-street" target=_blank>https://data.police.uk/api/crimes-street</a>. The location of the data is known as its *endpoint*.
#
# We can usually find all of the information we need by reading the API's documentation e.g., <a href="https://data.police.uk/docs/" target=_blank>https://data.police.uk/docs/</a>.
#
# Then we need to **do** the following:
# * Register your use of the API (if required).
# * Request data from the endpoint of interest, supplying authentication if required. This process is known as *making a call* to the API.
# * Write this data to a file for future use.
#
# For any programming task, it is useful to write out the steps needed to solve the problem: we call this *pseudo-code*, as it is captures the main tasks and the order in which they need to be executed.

# %% [markdown]
# ## A social science example
#
# Let's work through the steps in our general approach using a real API, one that provides data on policing activities and street-level crime in England, Wales and Northern Ireland: **UK Police API**.

# %% [markdown]
# ###  Locating the API
#
# The UK Police API can be accessed via the following web address or link: <a href="https://data.police.uk/api" target=_blank>https://data.police.uk/api</a>.
#
# Note that you cannot request this web address through your browser; this is because this link acts as the *base* web address from which you can access the different data sets. For example, we can access a list of all the police forces whose data is available via the API using the following web address: <a href="https://data.police.uk/api/forces" target=_blank>https://data.police.uk/api/forces</a>.
#
# **TASK**: Try it yourself: click on the above link to see what happens when you request data on police forces.
#
# Before delving further into requesting data, let's understand the terms of use/restrictions associated with the UK Police API.

# %% [markdown]
# ### API terms of use
#
# The UK Police API is reasonably well documented (not always the case, unfortunately) and we can clearly identify what is required in order to interact with it. Firstly, the API does not require authentication: you do not need to register your use of the API, nor provide a password (known as an API key) whenever you request data.
#
# Secondly, the API allows you to make up to 15 calls (requests) per second on average, though you can make up to 30 in a single second. If you are using the API for research purposes, it is highly unlikely you'll exceed this limit (but who knows what data requirements you have). There is no limit on the total number of calls you can make to the UK Police API as long as you comply with the aforementioned rate limits.
#
# See <a href="https://data.police.uk/docs/api-call-limits/" target=_blank>https://data.police.uk/docs/api-call-limits/</a> for full information on the API's call limits.
#
# To learn more about rate limiting as a concept, see [*Rate Limiting*](https://sicss.io/2020/materials/day2-digital-trace-data/apis/rmarkdown/Application_Programming_interfaces.html) (Bail, 2021).

# %% [markdown]
# ### Locating data
#
# The UK Police API allows access to over twenty endpoints (data sets), grouped under the following headings:
# * *Forces* e.g., senior officers
# * *Crime* e.g., crime categories
# * *Neighbourhoods* e.g., boundaries, events
# * *Stop and search* e.g., by area or force
#
# See <a href="https://data.police.uk/docs/" target=_blank>https://data.police.uk/docs/</a> for a complete list of endpoints accessible through this API.

# %% [markdown]
# ### Registering use of API
#
# We can skip this step as the UK Police API does not require us to register or provide any form of authentication (a good example of *open data*).

# %% [markdown]
# ### Requesting data
#
# We're ready for the interesting bit: requesting data through the API. To focus our activities, we'll attempt to do the following:
# 1. Download a list of police forces in the UK.
# 2. For each force, download its stop-and-search data.
# 3. Save all of the downloaded data to a file for future use.
#
# Before we download data, we need to ensure Python has the functionality it needs to interact with the API.

# %%
# Import modules

import os # module for navigating your machine (e.g., file directories)
import requests # module for requesting urls
import json # module for working with JSON data structures
import pandas as pd # module for working with datasets
from datetime import datetime # module for working with dates and time
print("Succesfully imported necessary modules")
# Out:
# Succesfully imported necessary modules

# %% [markdown]
# Modules are additional techniques or functions that are not present when you launch Python. Some do not even come with Python when you download it and must be installed on your machine separately - think of using `ssc install <package>` in Stata, or `install.packages(<package>)` in R. For now just understand that many useful modules need to be imported every time you start a new Python session.

# %%
# Define web address and search terms

baseurl = "https://data.police.uk/api/" # base web address
forces = "forces" # endpoint where forces data is located

webadd = baseurl + forces # construct web address to request
print(webadd)

# Make call to API

response = requests.get(webadd) # request the web address
response.status_code # check if API was requested successfully
# Out:
# https://data.police.uk/api/forces
# 200

# %% [markdown]
# Let's unpack the above code. First, we define a variable (also known as an 'object' in Python) called `baseurl` that contains the base web address of the UK Police API. Then we define a variable containing the endpoint we want to access data from (`forces`). Finally we concatenate these separate elements to form a valid web address that can be requested from the API (`webadd`).
#
# The next step is to use the `get()` method of the `requests` module to request the web address, and in the same line of code, we store the results of the request in a variable called `response`. Finally, we check whether the request was successful by calling on the `status_code` attribute of the `response` variable.
#
# We get a status code of *200*, which means the request was successful. A status code in the *400s* or *500s* represent an unsuccessful attempt at requesting a web address (see <a href="https://www.textbook.ds100.org/ch/07/web_http.html" target=_blank>Lau, Gonzalez and Nolan</a> for a succinct description of different types of response status codes).

# %% [markdown]
# You may be wondering exactly what it is we requested. To see the content of our request i.e., the data, we can call the `json()` method on the `response` variable:

# %%
forces_data = response.json()
forces_data
# Out:
# [{'id': 'avon-and-somerset', 'name': 'Avon and Somerset Constabulary'},
#  {'id': 'bedfordshire', 'name': 'Bedfordshire Police'},
#  {'id': 'cambridgeshire', 'name': 'Cambridgeshire Constabulary'},
#  {'id': 'cheshire', 'name': 'Cheshire Constabulary'},
#  {'id': 'city-of-london', 'name': 'City of London Police'},
#  {'id': 'cleveland', 'name': 'Cleveland Police'},
#  {'id': 'cumbria', 'name': 'Cumbria Constabulary'},
#  {'id': 'derbyshire', 'name': 'Derbyshire Constabulary'},
#  {'id': 'devon-and-cornwall', 'name': 'Devon & Cornwall Police'},
#  {'id': 'dorset', 'name': 'Dorset Police'},
#  {'id': 'durham', 'name': 'Durham Constabulary'},
#  {'id': 'dyfed-powys', 'name': 'Dyfed-Powys Police'},
#  {'id': 'essex', 'name': 'Essex Police'},
#  {'id': 'gloucestershire', 'name': 'Gloucestershire Constabulary'},
#  {'id': 'greater-manchester', 'name': 'Greater Manchester Police'},
#  {'id': 'gwent', 'name': 'Gwent Police'},
#  {'id': 'hampshire', 'name': 'Hampshire Constabulary'},
#  {'id': 'hertfordshire', 'name': 'Hertfordshire Constabulary'},
#  {'id': 'humberside', 'name': 'Humberside Police'},
#  {'id': 'kent', 'name': 'Kent Police'},
#  {'id': 'lancashire', 'name': 'Lancashire Constabulary'},
#  {'id': 'leicestershire', 'name': 'Leicestershire Police'},
#  {'id': 'lincolnshire', 'name': 'Lincolnshire Police'},
#  {'id': 'merseyside', 'name': 'Merseyside Police'},
#  {'id': 'metropolitan', 'name': 'Metropolitan Police Service'},
#  {'id': 'norfolk', 'name': 'Norfolk Constabulary'},
#  {'id': 'north-wales', 'name': 'North Wales Police'},
#  {'id': 'north-yorkshire', 'name': 'North Yorkshire Police'},
#  {'id': 'northamptonshire', 'name': 'Northamptonshire Police'},
#  {'id': 'northumbria', 'name': 'Northumbria Police'},
#  {'id': 'nottinghamshire', 'name': 'Nottinghamshire Police'},
#  {'id': 'northern-ireland', 'name': 'Police Service of Northern Ireland'},
#  {'id': 'south-wales', 'name': 'South Wales Police'},
#  {'id': 'south-yorkshire', 'name': 'South Yorkshire Police'},
#  {'id': 'staffordshire', 'name': 'Staffordshire Police'},
#  {'id': 'suffolk', 'name': 'Suffolk Constabulary'},
#  {'id': 'surrey', 'name': 'Surrey Police'},
#  {'id': 'sussex', 'name': 'Sussex Police'},
#  {'id': 'thames-valley', 'name': 'Thames Valley Police'},
#  {'id': 'warwickshire', 'name': 'Warwickshire Police'},
#  {'id': 'west-mercia', 'name': 'West Mercia Police'},
#  {'id': 'west-midlands', 'name': 'West Midlands Police'},
#  {'id': 'west-yorkshire', 'name': 'West Yorkshire Police'},
#  {'id': 'wiltshire', 'name': 'Wiltshire Police'}]

# %% [markdown]
# Note how we called the `json()` method on the `response` variable. This is because the data is returned to us in a structure known as *JSON*. JSON (Javascript Object Notation) is a hierarchical data structure based on key-value pairs (known as *items*), which are separated by commas (Brooker, 2020; Tagliaferri, n.d.). For example, the `name` key stores a value referring to the name of the police force.
#
# A JSON data structure (known in Python as a *dictionary* data type) can be difficult to understand at first, in no small part due to the unappealing presentation format. Visually, it is worth noting that this data structure begins and ends with curly braces (`{}`).

# %% [markdown]
# And Voila, we have a list of police forces in the UK (excluding Scotland and the British Transport Police).
#
# We hope you agree that requesting data from an API is a relatively simple task. The real challenge lies with the way the data are *structured* in response to your request. While sometimes you may be able to request data in a tabular format (e.g., a CSV or Excel file), most of the time it arrives looking a bit different than you may be familiar with. For instance, we currently have a list of police forces, and for each one there are two fields: `id` and `name`.
#
# Therefore we need to figure out how to navigate these results and extract information of interest. Thankfully Python provides some intuitive methods for performing this task.

# %% [markdown]
# #### Working with lists
#
# A *list* is a data type in Python that contains ordered, mutable sequences of elements. Think of it as a variable that contains a certain type of value, just a like an *integer* variable can only contain whole numbers, or a *string* variable contains characters that should be treated as text. Knowing which data type you're working with is crucial as it determines the kind of operations you can perform on the variable:

# %%
my_number = 25
my_string = "Hello there!"

print(my_number + 50) # this will work
print(my_string + 50) # this will not
# Out:
# 75
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-639ac900777f> in <module>
#       3
#       4 print(my_number + 50) # this will work
# ----> 5 print(my_string + 50) # this will not
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# The first thing to know is that we can confirm what data type a variable is:

# %%
type(forces_data)
# Out:
# list

# %% [markdown]
# We can also identify a list by the presence of opening and closing square brackets (`[]`).

# %% [markdown]
# Next, we can count how many elements a list contains like so:

# %%
len(forces_data)
# Out:
# 44

# %% [markdown]
# And we can view each element in a list as follows:

# %%
for force in forces_data:
    print(force)
    print("\r")
# Out:
# {'id': 'avon-and-somerset', 'name': 'Avon and Somerset Constabulary'}
#
# {'id': 'bedfordshire', 'name': 'Bedfordshire Police'}
#
# {'id': 'cambridgeshire', 'name': 'Cambridgeshire Constabulary'}
#
# {'id': 'cheshire', 'name': 'Cheshire Constabulary'}
#
# {'id': 'city-of-london', 'name': 'City of London Police'}
#
# {'id': 'cleveland', 'name': 'Cleveland Police'}
#
# {'id': 'cumbria', 'name': 'Cumbria Constabulary'}
#
# {'id': 'derbyshire', 'name': 'Derbyshire Constabulary'}
#
# {'id': 'devon-and-cornwall', 'name': 'Devon & Cornwall Police'}
#
# {'id': 'dorset', 'name': 'Dorset Police'}
#
# {'id': 'durham', 'name': 'Durham Constabulary'}
#
# {'id': 'dyfed-powys', 'name': 'Dyfed-Powys Police'}
#
# {'id': 'essex', 'name': 'Essex Police'}
#
# {'id': 'gloucestershire', 'name': 'Gloucestershire Constabulary'}
#
# {'id': 'greater-manchester', 'name': 'Greater Manchester Police'}
#
# {'id': 'gwent', 'name': 'Gwent Police'}
#
# {'id': 'hampshire', 'name': 'Hampshire Constabulary'}
#
# {'id': 'hertfordshire', 'name': 'Hertfordshire Constabulary'}
#
# {'id': 'humberside', 'name': 'Humberside Police'}
#
# {'id': 'kent', 'name': 'Kent Police'}
#
# {'id': 'lancashire', 'name': 'Lancashire Constabulary'}
#
# {'id': 'leicestershire', 'name': 'Leicestershire Police'}
#
# {'id': 'lincolnshire', 'name': 'Lincolnshire Police'}
#
# {'id': 'merseyside', 'name': 'Merseyside Police'}
#
# {'id': 'metropolitan', 'name': 'Metropolitan Police Service'}
#
# {'id': 'norfolk', 'name': 'Norfolk Constabulary'}
#
# {'id': 'north-wales', 'name': 'North Wales Police'}
#
# {'id': 'north-yorkshire', 'name': 'North Yorkshire Police'}
#
# {'id': 'northamptonshire', 'name': 'Northamptonshire Police'}
#
# {'id': 'northumbria', 'name': 'Northumbria Police'}
#
# {'id': 'nottinghamshire', 'name': 'Nottinghamshire Police'}
#
# {'id': 'northern-ireland', 'name': 'Police Service of Northern Ireland'}
#
# {'id': 'south-wales', 'name': 'South Wales Police'}
#
# {'id': 'south-yorkshire', 'name': 'South Yorkshire Police'}
#
# {'id': 'staffordshire', 'name': 'Staffordshire Police'}
#
# {'id': 'suffolk', 'name': 'Suffolk Constabulary'}
#
# {'id': 'surrey', 'name': 'Surrey Police'}
#
# {'id': 'sussex', 'name': 'Sussex Police'}
#
# {'id': 'thames-valley', 'name': 'Thames Valley Police'}
#
# {'id': 'warwickshire', 'name': 'Warwickshire Police'}
#
# {'id': 'west-mercia', 'name': 'West Mercia Police'}
#
# {'id': 'west-midlands', 'name': 'West Midlands Police'}
#
# {'id': 'west-yorkshire', 'name': 'West Yorkshire Police'}
#
# {'id': 'wiltshire', 'name': 'Wiltshire Police'}

# %% [markdown]
# Finally, we can access a particular element in a list by referring to its location (i.e., positional value or index). For example, which police force is located in position 10 in the list?

# %%
forces_data[9]
# Out:
# {'id': 'dorset', 'name': 'Dorset Police'}

# %% [markdown]
# Python begins counting at zero, hence why the value "9" refers to position "10" in the list. Simple rule of thumb: element *n* is located in position *n-1* in the list.

# %% [markdown]
# **TASK**: extract a different police force from the list using another index value.

# %%
forces_data[INSERT_INDEX_VALUE]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ecdf3a30c4bf> in <module>
# ----> 1 forces_data[INSERT_INDEX_VALUE]
#
# NameError: name 'INSERT_INDEX_VALUE' is not defined

# %% [markdown]
# OK, now that we're familiar with lists we can extract the `id` for each force and store them in a separate list like so:

# %%
force_ids = [force["id"] for force in forces_data]
force_ids
# Out:
# ['avon-and-somerset',
#  'bedfordshire',
#  'cambridgeshire',
#  'cheshire',
#  'city-of-london',
#  'cleveland',
#  'cumbria',
#  'derbyshire',
#  'devon-and-cornwall',
#  'dorset',
#  'durham',
#  'dyfed-powys',
#  'essex',
#  'gloucestershire',
#  'greater-manchester',
#  'gwent',
#  'hampshire',
#  'hertfordshire',
#  'humberside',
#  'kent',
#  'lancashire',
#  'leicestershire',
#  'lincolnshire',
#  'merseyside',
#  'metropolitan',
#  'norfolk',
#  'north-wales',
#  'north-yorkshire',
#  'northamptonshire',
#  'northumbria',
#  'nottinghamshire',
#  'northern-ireland',
#  'south-wales',
#  'south-yorkshire',
#  'staffordshire',
#  'suffolk',
#  'surrey',
#  'sussex',
#  'thames-valley',
#  'warwickshire',
#  'west-mercia',
#  'west-midlands',
#  'west-yorkshire',
#  'wiltshire']

# %% [markdown]
# To construct our list of force ids, we've made use of an intermediate technique in Python: *list comprehension*.
#
# We create a new list called `force_ids`, and we populate this variable with the values from the `id` field for each element (`el`) in the list (`forces_data`).

# %% [markdown]
# #### Stop-and-search data
#
# Now that we have a list of force ids we can request their respective stop-and-search data. For now, let's simplify our task by requesting data for *City of London* police force.

# %%
baseurl = "https://data.police.uk/api/" # base web address
sas = "stops-force" # stop-and-search endpoint
force = "city-of-london" # particular force to download data for

webadd = baseurl + sas + "?force=" + force # construct the web address for that force
print(webadd)
    
response = requests.get(webadd) # request the web address
response.status_code # check if API was requested successfully
    
sas_data = response.json() # store the data in a variable "sas_data"

for el in sas_data: # for every stop-and-search record
    el["force"] = force # add a new field to the data
# Out:
# https://data.police.uk/api/stops-force?force=city-of-london

# %% [markdown]
# The above code utilises many of the techniques we've seen before. The only new addition is the following:

# %% [raw]
# for el in sas_data:
#     el["force"] = force

# %% [markdown]
# This loop adds a new field to each stop-and-search record, as the original data doesn't make it clear which police force it refers to.
#
# Let's look at the data itself:

# %%
sas_data
# Out:
# [{'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-01T12:59:10+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-01T01:03:59+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-01T01:24:03+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-01T03:55:57+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-01T07:47:53+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.512650',
#    'street': {'id': 587331, 'name': "On or near St Andrew'S Hill"},
#    'longitude': '-0.101452'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-01T08:27:06+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.511625',
#    'street': {'id': 587234, 'name': 'On or near Mincing Lane'},
#    'longitude': '-0.081549'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-02T02:41:24+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.517576',
#    'street': {'id': 587303, 'name': 'On or near Police Station'},
#    'longitude': '-0.079786'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-02T03:01:36+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.513447',
#    'street': {'id': 587517, 'name': 'On or near Bow Lane'},
#    'longitude': '-0.093493'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-02T04:51:21+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.516351',
#    'street': {'id': 587285, 'name': 'On or near Wormwood Street'},
#    'longitude': '-0.082965'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-02T10:14:18+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.513171',
#    'street': {'id': 587277, 'name': 'On or near Aldgate'},
#    'longitude': '-0.077694'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-02T06:38:39+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-02T06:44:53+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Irish',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-02T06:56:31+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-02T07:05:37+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-02T07:49:59+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Any other ethnic group',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-02T08:00:25+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '51.514547',
#    'street': {'id': 956264, 'name': 'On or near Bell Yard'},
#    'longitude': '-0.112039'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'Penalty Notice for Disorder',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-02T08:14:33+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-penalty-notice',
#    'name': 'Penalty Notice for Disorder'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-02T09:16:34+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.511749',
#    'street': {'id': 587552, 'name': 'On or near Temple Avenue'},
#    'longitude': '-0.108018'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': None,
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-03T01:56:16+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512388',
#    'street': {'id': 587423, 'name': 'On or near King William Street'},
#    'longitude': '-0.088075'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-03T04:50:43+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-03T04:58:01+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.515031',
#    'street': {'id': 587319, 'name': 'On or near Warwick Lane'},
#    'longitude': '-0.100748'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T07:18:51+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509848',
#    'street': {'id': 587368, 'name': 'On or near A201'},
#    'longitude': '-0.104494'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T09:22:37+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.514507',
#    'street': {'id': 587215, 'name': 'On or near Undershaft'},
#    'longitude': '-0.081832'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T02:50:01+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516476',
#    'street': {'id': 587585, 'name': 'On or near Cursitor Street'},
#    'longitude': '-0.111181'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T03:46:29+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.518029',
#    'street': {'id': 587656, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-0.082722'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T06:38:06+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.517231',
#    'street': {'id': 587288, 'name': 'On or near New Street'},
#    'longitude': '-0.079613'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T06:56:42+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.513627',
#    'street': {'id': 587278, 'name': 'On or near Aldgate'},
#    'longitude': '-0.076435'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-04T06:58:54+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512882',
#    'street': {'id': 587435, 'name': 'On or near Corbet Court'},
#    'longitude': '-0.084768'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-04T07:07:33+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.513129',
#    'street': {'id': 587515, 'name': 'On or near Bread Street'},
#    'longitude': '-0.094933'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T07:29:09+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T08:30:05+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516814',
#    'street': {'id': 587299, 'name': "On or near Alderman'S Walk"},
#    'longitude': '-0.081620'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T08:36:05+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.514763',
#    'street': {'id': 587210, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-0.075508'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T08:37:26+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T08:59:46+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.517146',
#    'street': {'id': 587377, 'name': 'On or near Little Britain'},
#    'longitude': '-0.098642'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-04T09:02:42+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.513129',
#    'street': {'id': 587515, 'name': 'On or near Bread Street'},
#    'longitude': '-0.094933'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-05T03:52:53+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.515031',
#    'street': {'id': 587319, 'name': 'On or near Warwick Lane'},
#    'longitude': '-0.100748'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-05T06:17:26+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '51.512888',
#    'street': {'id': 587461, 'name': 'On or near Watling Court'},
#    'longitude': '-0.094482'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-05T06:26:36+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '51.512888',
#    'street': {'id': 587461, 'name': 'On or near Watling Court'},
#    'longitude': '-0.094482'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-05T09:04:50+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512856',
#    'street': {'id': 587309, 'name': 'On or near Mansell Street'},
#    'longitude': '-0.073254'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-05T09:21:10+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '51.512147',
#    'street': {'id': 587463, 'name': 'On or near Tower Royal'},
#    'longitude': '-0.092077'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-05T09:43:19+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512147',
#    'street': {'id': 587463, 'name': 'On or near Tower Royal'},
#    'longitude': '-0.092077'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-05T09:46:45+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512147',
#    'street': {'id': 587463, 'name': 'On or near Tower Royal'},
#    'longitude': '-0.092077'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-07T12:48:23+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.509547',
#    'street': {'id': 955927, 'name': 'On or near Tower Hill'},
#    'longitude': '-0.076031'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-07T03:55:44+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512856',
#    'street': {'id': 587309, 'name': 'On or near Mansell Street'},
#    'longitude': '-0.073254'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T06:20:10+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.517576',
#    'street': {'id': 587303, 'name': 'On or near Police Station'},
#    'longitude': '-0.079786'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T06:31:35+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.517576',
#    'street': {'id': 587303, 'name': 'On or near Police Station'},
#    'longitude': '-0.079786'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T06:41:58+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.517576',
#    'street': {'id': 587303, 'name': 'On or near Police Station'},
#    'longitude': '-0.079786'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T07:41:58+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.517576',
#    'street': {'id': 587303, 'name': 'On or near Police Station'},
#    'longitude': '-0.079786'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T11:03:52+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T01:01:57+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-07T02:29:13+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516814',
#    'street': {'id': 587299, 'name': "On or near Alderman'S Walk"},
#    'longitude': '-0.081620'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-07T05:45:27+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.512108',
#    'street': {'id': 587350, 'name': 'On or near Distaff Lane'},
#    'longitude': '-0.097973'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-07T10:36:49+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-07T10:46:30+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-08T04:30:28+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.518226',
#    'street': {'id': 956268, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-0.111497'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-08T05:35:41+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-08T09:30:55+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512598',
#    'street': {'id': 587443, 'name': 'On or near Bell Inn Yard'},
#    'longitude': '-0.084967'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-09T02:04:59+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.518864',
#    'street': {'id': 587604, 'name': 'On or near Parking Area'},
#    'longitude': '-0.097562'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-09T04:32:45+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-09T06:38:22+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-09T08:36:45+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.523901',
#    'street': {'id': 961236, 'name': 'On or near Honduras Street'},
#    'longitude': '-0.096011'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-10T04:40:14+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516191',
#    'street': {'id': 587535, 'name': 'On or near Throgmorton Avenue'},
#    'longitude': '-0.086416'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
# ...
#   'force': 'city-of-london'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-25T09:55:45+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons',
#   'force': 'city-of-london'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-25T10:19:45+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516814',
#    'street': {'id': 587299, 'name': "On or near Alderman'S Walk"},
#    'longitude': '-0.081620'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-25T11:51:15+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.517244',
#    'street': {'id': 587302, 'name': 'On or near Supermarket'},
#    'longitude': '-0.080376'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T02:02:53+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512598',
#    'street': {'id': 587443, 'name': 'On or near Bell Inn Yard'},
#    'longitude': '-0.084967'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-26T02:37:01+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512598',
#    'street': {'id': 587443, 'name': 'On or near Bell Inn Yard'},
#    'longitude': '-0.084967'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T03:02:13+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.512598',
#    'street': {'id': 587443, 'name': 'On or near Bell Inn Yard'},
#    'longitude': '-0.084967'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T04:05:49+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516814',
#    'street': {'id': 587299, 'name': "On or near Alderman'S Walk"},
#    'longitude': '-0.081620'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-26T05:56:19+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516370',
#    'street': {'id': 587300, 'name': 'On or near Conference/Exhibition Centre'},
#    'longitude': '-0.081912'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T05:17:35+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T05:19:15+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T05:20:28+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T05:24:19+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T05:25:42+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T05:26:37+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.510671',
#    'street': {'id': 587431, 'name': 'On or near Eastcheap'},
#    'longitude': '-0.084284'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T07:37:46+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.513454',
#    'street': {'id': 587521, 'name': 'On or near Supermarket'},
#    'longitude': '-0.091720'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-26T08:20:23+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.517576',
#    'street': {'id': 587303, 'name': 'On or near Police Station'},
#    'longitude': '-0.079786'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods',
#   'force': 'city-of-london'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-27T01:46:36+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.516814',
#    'street': {'id': 587299, 'name': "On or near Alderman'S Walk"},
#    'longitude': '-0.081620'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons',
#   'force': 'city-of-london'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2022-02-27T09:48:12+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.517231',
#    'street': {'id': 587288, 'name': 'On or near New Street'},
#    'longitude': '-0.079613'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs',
#   'force': 'city-of-london'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-27T06:57:48+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.511478',
#    'street': {'id': 587345, 'name': 'On or near Lambeth Hill'},
#    'longitude': '-0.096846'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2022-02-28T01:06:44+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '51.513394',
#    'street': {'id': 587433, 'name': 'On or near Cornhill'},
#    'longitude': '-0.084199'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft',
#   'force': 'city-of-london'}]

# %% [markdown]
# And how many records are returned:
#
# (Note that by default only records relating the most recent month are returned. You can search for other dates: see the <a href="https://data.police.uk/docs/method/stops-force/" taregt=_blank>documentation</a> for how to specify this option.

# %%
len(sas_data)
# Out:
# 170

# %% [markdown]
# ### Saving results
#
# The final task is to save the data to a file that we can use in the future. We'll write the data to a JSON file format, as this is the structure the data were returned in.

# %%
# Create a downloads folder

try:
    os.mkdir("./downloads")
except:
    print("Unable to create folder: already exists")

# %% [markdown]
# The use of "./" tells the `os.mkdir()` command that the "downloads" folder should be created at the same level of the directory where this notebook is located. So if this notebook was stored in a directory located at "C:/Users/joebloggs/notebooks", the `os.mkdir()` command would result in a new folder located at "C:/Users/joebloggs/notebooks/downloads".
#
# (Technically the "./" is not needed and you could just write `os.mkdir("downloads")` but it's good practice to be explicit.)

# %%
# Write the results to a JSON file

date = datetime.now().strftime("%Y-%m-%d") # get today's date in YYYY-MM-DD format
print(date)

forces_outfile = "./downloads/uk-police-forces-" + date + ".json"
col_outfile = "./downloads/city-of-london-sas-" + date + ".json"

with open(forces_outfile, "w") as f:
    json.dump(forces_data, f)
    
with open(col_outfile, "w") as f:
    json.dump(sas_data, f)
# Out:
# 2022-05-05

# %% [markdown]
# How do we know this worked? The simplest way is to check whether a) the file was created, and b) the data were written to it.

# %%
# Check presence of file in current folder

os.listdir("./downloads")
# Out:
# ['city-of-london-sas-2022-05-05.json', 'uk-police-forces-2022-05-05.json']

# %%
# Open files and read (import) its contents

with open(forces_outfile, "r") as f:
    data = f.read()
    
data
# Out:
# '[{"id": "avon-and-somerset", "name": "Avon and Somerset Constabulary"}, {"id": "bedfordshire", "name": "Bedfordshire Police"}, {"id": "cambridgeshire", "name": "Cambridgeshire Constabulary"}, {"id": "cheshire", "name": "Cheshire Constabulary"}, {"id": "city-of-london", "name": "City of London Police"}, {"id": "cleveland", "name": "Cleveland Police"}, {"id": "cumbria", "name": "Cumbria Constabulary"}, {"id": "derbyshire", "name": "Derbyshire Constabulary"}, {"id": "devon-and-cornwall", "name": "Devon & Cornwall Police"}, {"id": "dorset", "name": "Dorset Police"}, {"id": "durham", "name": "Durham Constabulary"}, {"id": "dyfed-powys", "name": "Dyfed-Powys Police"}, {"id": "essex", "name": "Essex Police"}, {"id": "gloucestershire", "name": "Gloucestershire Constabulary"}, {"id": "greater-manchester", "name": "Greater Manchester Police"}, {"id": "gwent", "name": "Gwent Police"}, {"id": "hampshire", "name": "Hampshire Constabulary"}, {"id": "hertfordshire", "name": "Hertfordshire Constabulary"}, {"id": "humberside", "name": "Humberside Police"}, {"id": "kent", "name": "Kent Police"}, {"id": "lancashire", "name": "Lancashire Constabulary"}, {"id": "leicestershire", "name": "Leicestershire Police"}, {"id": "lincolnshire", "name": "Lincolnshire Police"}, {"id": "merseyside", "name": "Merseyside Police"}, {"id": "metropolitan", "name": "Metropolitan Police Service"}, {"id": "norfolk", "name": "Norfolk Constabulary"}, {"id": "north-wales", "name": "North Wales Police"}, {"id": "north-yorkshire", "name": "North Yorkshire Police"}, {"id": "northamptonshire", "name": "Northamptonshire Police"}, {"id": "northumbria", "name": "Northumbria Police"}, {"id": "nottinghamshire", "name": "Nottinghamshire Police"}, {"id": "northern-ireland", "name": "Police Service of Northern Ireland"}, {"id": "south-wales", "name": "South Wales Police"}, {"id": "south-yorkshire", "name": "South Yorkshire Police"}, {"id": "staffordshire", "name": "Staffordshire Police"}, {"id": "suffolk", "name": "Suffolk Constabulary"}, {"id": "surrey", "name": "Surrey Police"}, {"id": "sussex", "name": "Sussex Police"}, {"id": "thames-valley", "name": "Thames Valley Police"}, {"id": "warwickshire", "name": "Warwickshire Police"}, {"id": "west-mercia", "name": "West Mercia Police"}, {"id": "west-midlands", "name": "West Midlands Police"}, {"id": "west-yorkshire", "name": "West Yorkshire Police"}, {"id": "wiltshire", "name": "Wiltshire Police"}]'

# %% [markdown]
# **TASK**: Load in the City of London stop-and-search data.

# %%
with open(col_outfile, "r") as f:
    data = f.read()
    
data
# Out:
# '[{"age_range": "10-17", "outcome": "A no further action disposal", "involved_person": true, "self_defined_ethnicity": "Other ethnic group - Not stated", "gender": "Female", "legislation": "Police and Criminal Evidence Act 1984 (section 1)", "outcome_linked_to_object_of_search": false, "datetime": "2022-02-01T12:59:10+00:00", "removal_of_more_than_outer_clothing": false, "outcome_object": {"id": "bu-no-further-action", "name": "A no further action disposal"}, "location": {"latitude": "51.509848", "street": {"id": 587368, "name": "On or near A201"}, "longitude": "-0.104494"}, "operation": null, "officer_defined_ethnicity": "White", "type": "Person search", "operation_name": null, "object_of_search": "Stolen goods", "force": "city-of-london"}, {"age_range": "25-34", "outcome": "A no further action disposal", "involved_person": true, "self_defined_ethnicity": "Other ethnic group - Not stated", "gender": "Female", "legislation": "Police and Criminal Evidence Act 1984 (section 1)", "outcome_linked_to_object_of_search": false, "datetime": "2022-02-01T01:03:59+00:00", "removal_of_more_than_outer_clothing": false, "outcome_object": {"id": "bu-no-further-action", "name": "A no further action disposal"}, "location": {"latitude": "51.509848", "street": {"id": 587368, "name": "On or near A201"}, "longitude": "-0.104494"}, "operation": null, "officer_defined_ethnicity": "White", "type": "Person search", "operation_name": null, "object_of_search": "Stolen goods", "force": "city-of-london"}, {"age_range": "10-17", "outcome": "A no further action disposal", "involved_person": true, "self_defined_ethnicity": "Other ethnic group - Not stated", "gender": "Male", "legislation": "Police and Criminal Evidence Act 1984 (section 1)", "outcome_linked_to_object_of_search": false, "datetime": "2022-02-01T01:24:03+00:00", "removal_of_more_than_outer_clothing": false, "outcome_object": {"id": "bu-no-further-action", "name": "A no further action disposal"}, "location": {"latitude": "51.509848", "street": {"id": 587368, "name": "On or near A201"}, "longitude": "-0.104494"}, "operation": null, "officer_defined_ethnicity": "White", "type": "Person search", "operation_name": null, "object_of_search": "Article for use in theft", "force": "city-of-london"}, {"age_range": "25-34", "outcome": "A no further action disposal", "involved_person": true, "self_defined_ethnicity": "White - Any other White background", "gender": "Male", "legislation": "Misuse of Drugs Act 1971 (section 23)", "outcome_linked_to_object_of_search": false, "datetime": "2022-02-01T03:55:57+00:00", "removal_of_more_than_outer_clothing": false, "outcome_object": {"id": "bu-no-further-action", "name": "A no further action disposal"}, "location": null, "operation": null, "officer_defined_ethnicity": "White", "type": "Person search", "operation_name": null, "object_of_search": "Controlled drugs", "force": "city-of-london"}, {"age_range": "25-34", "outcome": "Arrest", "involved_person": true, "self_defined_ethnicity": "White - English/Welsh/Scottish/Northern Irish/British", "gender": "Male", "legislation": "Misuse of Drugs Act 1971 (section 23)", "outcome_linked_to_object_of_search": true, "datetime": "2022-02-01T07:47:53+00:00", "removal_of_more_than_outer_clothing": false, "outcome_object": {"id": "bu-arrest", "name": "Arrest"}, "location": {"latitude": "51.512650", "street": {"id": 587331, "name": "On or near St Andrew\'S Hill"}, "longitude": "-0.101452"}, "operation": null, "officer_defined_ethnicity": "Black", "type": "Person and Vehicle search", "operation_name": null, "object_of_search": "Controlled drugs", "force": "city-of-london"}, {"age_range": "over 34", "outcome": "A no further action disposal", "involved_person": true, "self_defined_ethnicity": "Other ethnic group - Not stated", "gender": "Male", "legislation": "Police and Criminal Evidence Act 1984 (section 1)", "outcome_linked_to_object_of_search": true, "datetime": "2022-02-01T08:27:06+00:00", "removal_of_more_than_outer_clothing":  ...

# %% [markdown]
# ### Analysis

# %% [markdown]
# The purpose of all these interesting and computational methods is to produce data for some important analysis. So let's do a tiny bit just now, just to give you a sense of how JSON data can be analysed.
#
# First, let's convert JSON into a more familiar data structure (tabular or matrix).

# %%
df = pd.read_json(col_outfile)
df.sample(5)
# Out:
#     age_range                       outcome  involved_person  \
# 163      None  A no further action disposal             True
# 159      None  A no further action disposal             True
# 20      18-24  A no further action disposal             True
# 82      18-24  A no further action disposal             True
# 112     25-34  A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 163                                               None   Male
# 159                                               None   Male
# 20   White - English/Welsh/Scottish/Northern Irish/...   Male
# 82                     Other ethnic group - Not stated   Male
# 112                    Other ethnic group - Not stated   Male
#
#                                            legislation  \
# 163  Police and Criminal Evidence Act 1984 (section 1)
# 159  Police and Criminal Evidence Act 1984 (section 1)
# 20   Police and Criminal Evidence Act 1984 (section 1)
# 82   Police and Criminal Evidence Act 1984 (section 1)
# 112              Misuse of Drugs Act 1971 (section 23)
#
#      outcome_linked_to_object_of_search                  datetime  \
# 163                               False 2022-02-26 05:26:37+00:00
# 159                               False 2022-02-26 05:19:15+00:00
# 20                                False 2022-02-03 04:58:01+00:00
# 82                                False 2022-02-14 02:56:00+00:00
# 112                               False 2022-02-19 05:06:12+00:00
#
#      removal_of_more_than_outer_clothing  \
# 163                                False
# 159                                False
# 20                                 False
# 82                                 False
# 112                                False
#
#                                         outcome_object  \
# 163  {'id': 'bu-no-further-action', 'name': 'A no f...
# 159  {'id': 'bu-no-further-action', 'name': 'A no f...
# 20   {'id': 'bu-no-further-action', 'name': 'A no f...
# 82   {'id': 'bu-no-further-action', 'name': 'A no f...
# 112  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                               location  operation  \
# 163  {'latitude': '51.510671', 'street': {'id': 587...        NaN
# 159  {'latitude': '51.510671', 'street': {'id': 587...        NaN
# 20   {'latitude': '51.515031', 'street': {'id': 587...        NaN
# 82   {'latitude': '51.519812', 'street': {'id': 587...        NaN
# 112                                               None        NaN
#
#     officer_defined_ethnicity           type  operation_name  \
# 163                      None  Person search             NaN
# 159                      None  Person search             NaN
# 20                      White  Person search             NaN
# 82                      Black  Person search             NaN
# 112                     Black  Person search             NaN
#
#              object_of_search           force
# 163  Article for use in theft  city-of-london
# 159  Article for use in theft  city-of-london
# 20   Article for use in theft  city-of-london
# 82               Stolen goods  city-of-london
# 112          Controlled drugs  city-of-london

# %% [markdown]
# While there is still some hierarchical data to be unpacked (see the `location` field), the data are now easier to inspect and analyse.

# %% [markdown]
# Let's do a quick analysis of the age of the individual who was stopped and the outcome of the stop-and-search.

# %%
pd.crosstab(index=df['outcome'], columns=df['age_range'], normalize='columns').round(2)*100 # convert from proportions to percentages
# Out:
# age_range                     10-17  18-24  25-34  over 34
# outcome
# A no further action disposal  100.0   87.0   69.0     76.0
# Arrest                          0.0   10.0   25.0     16.0
# Community resolution            0.0    0.0    2.0      3.0
# Khat or Cannabis warning        0.0    4.0    4.0      3.0
# Penalty Notice for Disorder     0.0    0.0    0.0      3.0

# %% [markdown]
# 25-34 year olds are most likely to be arrested, followed by the over 34 year olds.

# %% [markdown]
# Finally, let's look at the reason why an individual was subjected to a stop-and-search.

# %%
pd.crosstab(index=df['object_of_search'], columns=df['age_range'], normalize='columns').round(2)*100 # convert from proportions to percentages
# Out:
# age_range                            10-17  18-24  25-34  over 34
# object_of_search
# Article for use in theft              38.0   17.0   23.0     43.0
# Articles for use in criminal damage    0.0    2.0    0.0      0.0
# Controlled drugs                       8.0   67.0   62.0     43.0
# Evidence of offences under the Act     0.0    4.0    2.0      0.0
# Offensive weapons                     38.0    0.0    4.0      3.0
# Stolen goods                          15.0   10.0    8.0     11.0

# %% [markdown]
# The youngest cohort was most likely to be stopped and searched for offensive weapons.

# %% [markdown]
# That concludes our whistlestop tour of the UK Police API. See Appendix A for an example of how you request stop-and-search data for **every** police force.

# %% [markdown]
# ## What have we learned?
#
# Let's recap what key skills and techniques we've learned:
# * **How to import modules**. You will usually need to import modules into Python to support your work. Python does come with some methods and functions that are ready to use straight away, but for computational social science tasks you'll almost certainly need to import some additional modules.
# * **How to make requests (calls) for data to an API**. You can use Python to request data from an API.
# * **How to handle and save the data that is returned by the API**. APIs tend to return data in JSON format, which requires different data manipulation techniques than you may be used to. You can process this data and save it to a file for future use.
# * **How to do all of the above in an efficient, clear and effective manner**.

# %% [markdown]
# ## Conclusion
#
# Interacting with an API is a simple yet powerful computational method for collecting data of value for social science research. It provides a relatively gentle introduction to using programming languages, also. However, "with great power comes great responsibility" (sorry). APIs take you into the realm of data protection, Terms of Service/Use, and many murky ethical issues. Wielded sensibly and sensitively, collecting data from APIs is a valuable and exciting social science research method.
#
# Good luck on your data-driven travels!

# %% [markdown]
# ## Exercise

# %% [markdown]
# ## Bibliography
#
# Bail, C. (2021). *Application Programming Interfaces*. <a href="https://sicss.io/overview/application-programming-interfaces" target=_blank>https://sicss.io/overview/application-programming-interfaces</a>
#
# Barba, Lorena A. et al. (2019). *Teaching and Learning with Jupyter*. <a href="https://jupyter4edu.github.io/jupyter-edu-book/" target=_blank>https://jupyter4edu.github.io/jupyter-edu-book/</a>.
#
# Brooker, P. (2020). *Programming with Python for Social Scientists*. London: SAGE Publications Ltd.
#
# Lau, S., Gonzalez, J., & Nolan, D. (n.d.). *Principles and Techniques of Data Science*. https://www.textbook.ds100.org
#
# Tagliaferri, L. (n.d.). *How to Code in Python 3*. https://assets.digitalocean.com/books/python/how-to-code-in-python.pdf

# %% [markdown]
# ## Appendices

# %% [markdown]
# ### Appendix A - Stop-and-search data for every police force
#
# It would be inefficient to request data for every police force one at a time. We can make use of lists and loops to speed up the downloading of data.
#
# First, let's get our list of police forces:

# %%
# Import modules

import os
import requests
import json
from datetime import datetime
print("Succesfully imported necessary modules")

# Define web address and search terms

baseurl = "https://data.police.uk/api/"
forces = "forces"
webadd = baseurl + forces

# Make call to API

response = requests.get(webadd)
response.status_code

# Store data in variable

forces_data = response.json()
# Out:
# Succesfully imported necessary modules

# %% [markdown]
# Next, we extract a list of force ids:

# %%
force_ids = [el["id"] for el in forces_data]

# %% [markdown]
# Then, for each of these ids we request stop-and-search data and store the results in a list:

# %%
baseurl = "https://data.police.uk/api/"
sas = "stops-force"

forces_sas_data = [] # create a blank list for storing results of request

for force in force_ids: 
    webadd = baseurl + sas + "?force=" + force
    
    response = requests.get(webadd)
    
    if response.status_code==200:
        sas_data = response.json()
    
        for el in sas_data:
            el["force"] = force
            el["code"] = response.status_code
            el["note"] = "Downloaded data"
    else:
        sas_data = {"force": force, "note": "Could not download", "code": response.status_code}
        
    forces_sas_data.append(sas_data)

# %% [markdown]
# You'll see we added a conditional statement (`if, else`) to check whether we made a successful request for data: if yes, then store the data in the `sas_data` variable; if no, then define the `sas_data` variable as a dictionary containing some notes about the unsuccessful attempt.
#
# Let's check the results. Our `data` list should contain the results for 44 police forces:

# %%
len(forces_sas_data)
# Out:
# 44

# %% [markdown]
# We'll leave it to you to examine the contents of the `forces_sas_data` variable.

# %% [markdown]
# --END OF FILE--
